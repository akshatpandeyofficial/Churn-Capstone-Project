# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\AKSHAT\Desktop\Telco_customer_churn.xlsx")
pd.set_option('Display.max_rows',None)
pd.set_option('Display.max_columns',None)
df

# %%
df.shape

# %%
df.columns

# %%
df["Gender"].value_counts()

# %%
df["Country"].value_counts()

# %%
df.info()

# %%
df.isna().sum()

# %%
df.duplicated().sum()

# %%
df.describe()

# %%
df.isna().sum().sort_values(ascending=False)

# %%
df.columns

# %%
df['Tenure Months'].value_counts().sort_index

# %%
df["Monthly Charges"].describe()

# %%
df["Total Charges"].describe()

# %%
df["Churn Score"].describe()

# %%
df["CLTV"].describe()

# %%
df["CustomerID"].duplicated().sum()

# %%
df["Contract"].value_counts()

# %%
df["Payment Method"].value_counts()

# %%
df["Churn Label"].value_counts()

# %%
df["Churn Reason"].value_counts()

# %%
df[df["Tenure Months"] == 0]

# %%
df["Streaming TV"].value_counts()

# %%
df.groupby("Churn Label")["Churn Reason"].apply(lambda x: x.isna().sum())

# %%
df.dtypes

# %%
df["Total Charges"]

# %%
df["Total Charges"].unique()[:20]

# %%
df["Total Charges"].isna().sum()

# %%
df[df["Total Charges"].astype(str).str.strip() == ""]

# %%
df["Total Charges"]=pd.to_numeric(df["Total Charges"], errors ="coerce")

# %%
df["Total Charges"].isna().sum()

# %%
df["Total Charges"]=df["Total Charges"].fillna(0)

# %%
df["Total Charges"].dtype

# %%
df
